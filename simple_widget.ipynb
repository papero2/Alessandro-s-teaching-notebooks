# %%
import ipywidgets as widgets
from ipywidgets.embed import embed_minimal_html
import matplotlib.pyplot as plt

@widgets.interact(x=1.0, y=1.0)
def g(x, y):
    return (x, y)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='x', max=3.0, min=-1.0), FloatSlider(value=1.0, descr…

# %%
import sys
print(widgets.__version__)
# Out:
# 7.4.2

# %% [markdown]
# ### Example From Jupyter Notebook Docs

# %%
widgets.IntSlider(
    value=7,
    min=0,
    max=10,
    step=1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
# Out:
# IntSlider(value=7, continuous_update=False, description='Test:', max=10)

# %% [markdown]
# ### Example Similar To Alessandro

# %%
import numpy as np
extent = (-1, 3, -1, 2)

@widgets.interact(i=widgets.IntSlider(min=0,max=10,step=1,value=0))
def f(i):
    terrain = np.zeros((10, 10))
#    terrain.fill(i/10)
    plt.imshow(terrain, vmin = 0, vmax = 1)
    return i
# Out:
# interactive(children=(IntSlider(value=0, description='i', max=10), Output()), _dom_classes=('widget-interact',…

# %%
def f():
    terrain = np.zeros((10, 10))
#    terrain.fill(i/10)
    plt.imshow(terrain, vmin = 0, vmax = 1)
f()
